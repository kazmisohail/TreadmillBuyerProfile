# %% [markdown]
# # Treadmill Buyer Profile
# ## Portfolio Project

# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Data Exploration and Processing:
# * Importing data
# * Reading dataframe
# * Check the shape of the dataframe
# * Datatype of each column
# * Missing value detection
# * Checking duplicate values in the dataset

# %%
data = pd.read_csv('aerofit_treadmill_data.csv')

# %%
print(f"Shape of DataFrame: {data.shape}")
# Out:
# Shape of DataFrame: (180, 9)

# %%
print(f"Data Types of each column: \n{data.dtypes}")
# Out:
# Data Types of each column:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
print(f"Missing Values: \n{data.isnull().sum()}")
# Out:
# Missing Values:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
print(f"Duplicate Values: {data.duplicated().sum()}")
# Out:
# Duplicate Values: 0

# %% [markdown]
# ## 2. Statistical Summary:
# * Provide an analysis of the statistical summary in few lines for both categorical and numerical features.

# %%
print(f"Statistical Summary of Categorical Features: \n{data.describe(include='object')}")
# Out:
# Statistical Summary of Categorical Features:
#        Product Gender MaritalStatus
# count      180    180           180
# unique       3      2             2
# top      KP281   Male     Partnered
# freq        80    104           107

# %%
print(f"Statistical Summary of Numerical Features: \n{data.describe()}")
# Out:
# Statistical Summary of Numerical Features:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# ## 3. Non-Graphical Analysis:
# * Value Counts for all categorical features
# * Unique Attributes for all categorical features

# %%
print("Value Counts for all categorical features")
i=1
for column in data.columns:
    if data[column].dtype == 'object':
        print(f"\n{i}. {data[column].value_counts()}")
        i+=1
# Out:
# Value Counts for all categorical features
#
# 1. Product
# KP281    80
# KP481    60
# KP781    40
# Name: count, dtype: int64
#
# 2. Gender
# Male      104
# Female     76
# Name: count, dtype: int64
#
# 3. MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
print("Unique Attributes for all categorical features")
j=1
for column in data.columns:
    if data[column].dtype == 'object':
        print(f"\n{j}. {column}\n{data[column].unique()}")
        j+=1
# Out:
# Unique Attributes for all categorical features
#
# 1. Product
# ['KP281' 'KP481' 'KP781']
#
# 2. Gender
# ['Male' 'Female']
#
# 3. MaritalStatus
# ['Single' 'Partnered']

# %% [markdown]
# ## 4. Graphical Analysis:
# * Univariate Analysis - Numerical features:
# ** Distribution Plot
# ** Count Plot
# ** Box Plot
# * Univariate Analysis - Categorical features:
# ** Count Plot
# * Bivariate Analysis:
# ** Check features eƯect on the product purchased e.g.
# ** Product vs Gender
# ** Product vs MaritalStatus
# ** Product vs Age
# * Multivariate Analysis:
# ** Create pairplots to show relationship of features

# %%
num_features = []
cat_features = []

# to separate numerical and categorical features for graphical analysis
for col in data.columns:
    if data[col].dtype == 'object':
        cat_features.append(col)
    else:
        num_features.append(col)

# %% [markdown]
# ### Distribution Plots for Numerical Features

# %%
for feature in num_features:
    sns.histplot(data[feature], color="skyblue")
    plt.title(f"Distribution of {feature}")
    plt.show()

# %% [markdown]
# ### Count Plots for Numerical Features

# %%
for feature in num_features:
    sns.countplot(data=data, x=feature, palette="pastel")
    plt.title(f"Count Plot of {feature}")
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.show()
# Out:
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\292675876.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=feature, palette="pastel")
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\292675876.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=feature, palette="pastel")
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\292675876.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=feature, palette="pastel")
# ...

# %% [markdown]
# ### Box Plots for Numerical Features

# %%
for feature in num_features:
    sns.boxplot(data=data, y=feature, palette="coolwarm")
    plt.title(f"Box Plot of {feature}")
    plt.ylabel(feature)
    plt.show()
# Out:
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\2350129779.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, y=feature, palette="coolwarm")
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\2350129779.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, y=feature, palette="coolwarm")
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\2350129779.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, y=feature, palette="coolwarm")
# ...

# %% [markdown]
# ### Count Plots for Categorical Features

# %%
for feature in cat_features:
    sns.countplot(data=data, x=feature, palette="pastel")
    plt.title(f"Count of {feature}")
    plt.show()
# Out:
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\1056659301.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=feature, palette="pastel")
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\1056659301.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=feature, palette="pastel")
# C:\Users\kazmi\AppData\Local\Temp\ipykernel_9224\1056659301.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x=feature, palette="pastel")

# %% [markdown]
# ### Bivariate Analysis

# %%
# Product vs Gender
sns.countplot(data=data, x="Product", hue="Gender", palette="pastel")
plt.title("Product vs Gender")
plt.show()

# %%
# Product vs MaritalStatus
sns.countplot(data=data, x="Product", hue="Gender", palette="muted")
plt.title("Product vs MaritalStatus")
plt.show()

# %%
# Product vs Age
sns.boxplot(data=data, x="Product", hue="Age", palette="coolwarm")
plt.title("Product vs Age")
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(data, hue="Product")
plt.show()

# %% [markdown]
# ## 5. Correlation Analysis:

# %%
num_data = data[num_features]
sns.heatmap(num_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## 6. Outlier Detection:
# * Check for the outliers by using the IQR method.

# %%
for feature in num_features:
    q1 = data[feature].quantile(0.25)
    q3 = data[feature].quantile(0.75)
    iqr = q3 - q1
    outliers = data[(data[feature] < (q1 - 1.5 * iqr)) | (data[feature] > (q3 + 1.5 * iqr))]
    print(f"\nOutliers for {feature}: {len(outliers)}")
# Out:
# Outliers for Age: 5
#
# Outliers for Education: 4
#
# Outliers for Usage: 9
#
# Outliers for Fitness: 2
#
# Outliers for Income: 19
#
# Outliers for Miles: 13

# %% [markdown]
# ## 7. Conditional Probabilities:

# %%
product_counts = data['Product'].value_counts()
print("Percentage of Customers by Product:\n", (product_counts / len(data)) * 100)
# Out:
# Percentage of Customers by Product:
#  Product
# KP281    44.444444
# KP481    33.333333
# KP781    22.222222
# Name: count, dtype: float64

# %% [markdown]
# ### product - gender

# %%
total_customers = len(data)
male_customers = len(data[data['Gender'] == 'Male'])
percent_male_customers = (male_customers / total_customers) * 100
print(f"Percentage of Male customers purchasing a treadmill: {percent_male_customers:.2f} %")
# Out:
# Percentage of Male customers purchasing a treadmill: 57.78 %

# %%
female_kp781 = len(data[(data['Gender'] == 'Female') & (data['Product'] == 'KP781')])
percent_female_kp781 = (female_kp781 / total_customers) * 100
print(f"Percentage of Female customers purchasing KP781: {percent_female_kp781:.2f} %")
# Out:
# Percentage of Female customers purchasing KP781: 3.89 %

# %%
female_given_kp281 = len(data[(data['Product'] == 'KP281') & (data['Gender'] == 'Female')]) / len(data[data['Product'] == 'KP281'])
print(f"Probability of a customer being Female given that Product is KP281: {female_given_kp281:.2f}")
# Out:
# Probability of a customer being Female given that Product is KP281: 0.50

# %% [markdown]
# ### product - age

# %%
age_20s_30s = len(data[(data['Age'] >= 20) & (data['Age'] < 40)])
percent_age_20s_30s = (age_20s_30s / total_customers) * 100
print(f"Percentage of customers aged between 20s and 30s: {percent_age_20s_30s:.2f} %")
# Out:
# Percentage of customers aged between 20s and 30s: 87.78 %

# %% [markdown]
# ### product - income

# %%
low_income_threshold = data['Income'].quantile(0.25)
high_income_threshold = data['Income'].quantile(0.75)

# %%
low_income_customers = len(data[data['Income'] < low_income_threshold])
percent_low_income_customers = (low_income_customers / total_customers) * 100
print(f"Percentage of low-income customers purchasing a treadmill: {percent_low_income_customers:.2f} %")
# Out:
# Percentage of low-income customers purchasing a treadmill: 25.00 %

# %%
high_income_kp781 = len(data[(data['Income'] > high_income_threshold) & (data['Product'] == 'KP781')])
percent_high_income_kp781 = (high_income_kp781 / total_customers) * 100
print(f"Percentage of high-income customers purchasing KP781: {percent_high_income_kp781:.2f} %")
# Out:
# Percentage of high-income customers purchasing KP781: 16.11 %

# %%
high_income_given_kp781 = (high_income_kp781 / len(data[data['Product'] == 'KP781'])) * 100
print(f"Probability of high-income salary given Product is KP781: {high_income_given_kp781:.2f} %")
# Out:
# Probability of high-income salary given Product is KP781: 72.50 %

# %% [markdown]
# ### product - fitness

# %%
fitness_5_customers = len(data[data['Fitness'] == 5])
percent_fitness_5 = (fitness_5_customers / total_customers) * 100
print(f"Percentage of customers with Fitness Level 5: {percent_fitness_5:.2f} %")
# Out:
# Percentage of customers with Fitness Level 5: 17.22 %

# %%
fitness_5_kp781 = len(data[(data['Fitness'] == 5) & (data['Product'] == 'KP781')])
percent_fitness_5_kp781 = (fitness_5_kp781 / total_customers) * 100
print(f"Percentage of customers with Fitness Level 5 purchasing KP781: {percent_fitness_5_kp781:.2f} %")
# Out:
# Percentage of customers with Fitness Level 5 purchasing KP781: 16.11 %

# %%
fitness_5_given_kp781 = fitness_5_kp781 / len(data[data['Product'] == 'KP781'])
print(f"Probability of Fitness Level 5 given KP781: {fitness_5_given_kp781:.2f}")
# Out:
# Probability of Fitness Level 5 given KP781: 0.72

# %% [markdown]
# ### product - marital status

# %%
partnered_customers = len(data[data['MaritalStatus'] == 'Partnered'])
percent_partnered_customers = (partnered_customers / total_customers) * 100
print(f"Percentage of partnered customers using treadmills: {percent_partnered_customers:.2f} %")
# Out:
# Percentage of partnered customers using treadmills: 59.44 %

# %% [markdown]
# ## 8. Actionable Insights & Recommendations:

# %% [markdown]
# Here are some insights that I noticed while performing conditional probabilities...
#
# Male customers make up a higher percentage of total treadmill buyers.
#
# A significant percentage of customers fall in the 20s and 30s age group.
#
# Partnered customers account is around 60% of total treadmill buyers, indicating that most buyers are likely part of families or households.
#
# KP281 has the highest customer percentage while KP781 has the lowest customer percentage.
